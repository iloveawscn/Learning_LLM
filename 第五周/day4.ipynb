# %% [markdown]
# # RAG 第四天
#
# 评估！请大家记住，在业务场景中该如何评估 RAG。这一点至关重要，是构建准确、可靠的 RAG 流水线的关键。而且，这不仅仅适用于 RAG，在利用 LLM 解决业务问题的许多方面，其实都是通用的。大家往往过于关注 RAG 架构和框架。但实际上，还有比这些更重要的环节，那就是——评估！

# %%
from evaluation import test

# %%
tests = test.load_tests()

# %%
len(tests)
# Out:
# 150

# %%
example = tests[0]
print(example.question)
print(example.category)
print(example.reference_answer)
print(example.keywords)
# Out:
# Who won the prestigious IIOTY award in 2023?
# direct_fact
# Maxine Thompson won the prestigious 1topcloudllm Innovator of the Year (IIOTY) award in 2023.
# ['Maxine', 'Thompson', 'IIOTY']

# %%
from collections import Counter
count = Counter([t.category for t in tests])
count
# Out:
# Counter({'direct_fact': 70,
#          'temporal': 20,
#          'spanning': 20,
#          'comparative': 10,
#          'numerical': 10,
#          'relationship': 10,
#          'holistic': 10})

# %%
from evaluation.eval import evaluate_retrieval, evaluate_answer

# %%
evaluate_retrieval(example)
# Out:
# RetrievalEval(mrr=0.09523809523809523, ndcg=0.2544144562483559, keywords_found=2, total_keywords=3, keyword_coverage=66.66666666666666)

# %%
eval, answer, chunks = evaluate_answer(example)

# %%
eval
# Out:
# AnswerEval(feedback="The answer correctly identifies Maxine as the winner of the IIOTY award in 2023, matching the reference that specifies Maxine Thompson. It provides additional context about her contributions, which, while informative, is not required by the question. The key factual detail about the winner's identity is accurate and complete.", accuracy=5.0, completeness=4.0, relevance=5.0)

# %%
print(eval.feedback)
print(eval.accuracy)
print(eval.completeness)
print(eval.relevance)
# Out:
# The answer correctly identifies Maxine as the winner of the IIOTY award in 2023, matching the reference that specifies Maxine Thompson. It provides additional context about her contributions, which, while informative, is not required by the question. The key factual detail about the winner's identity is accurate and complete.
# 5.0
# 4.0
# 5.0
